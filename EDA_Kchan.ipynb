# %%
import pandas as pd

# %%
df = pd.read_excel('Data\원본\자전거+이용환경+만족도_20240828141848.xlsx',header=[0,1])
df.head()
# Out:
#   구분별(1) 구분별(2) 2014
#   구분별(1) 구분별(2)   합계 매우 불만족 (%) 약간 불만족 (%) 보통 (%) 약간 만족 (%) 매우 만족 (%)
# 0    서울시     소계  100        1.9        8.6   29.9      50.8       8.8  \
# 1     성별     남자  100        1.8        8.2   28.7      51.9       9.3
# 2     성별     여자  100        1.9        9.4   32.2      48.6       7.9
# 3    연령별    10대  100        1.1       11.1   31.1      51.2       5.5
# 4    연령별    20대  100        2.1        8.3   32.6      48.2       8.8
#
#              2016  ...   2019                                      2023
#   10점 평균 (점)   합계  ... 보통 (%) 약간 만족 (%) 매우 만족 (%) 10점 평균 (점) 매우 불만족 (%)
# 0        6.4  100  ...   37.3      42.5       6.6       6.02        1.5  \
# 1       6.47  100  ...   37.4      42.7       6.7       6.04        1.3
# 2       6.28  100  ...   37.1      42.1       6.5       5.99          2
# 3       6.22  100  ...   38.7        39       8.9       6.07        0.2
# 4       6.33  100  ...     43      40.6       6.5       6.06        4.1
#
#
# ...
